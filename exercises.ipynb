# %%
import matplotlib.pyplot as plt

# %%
X = [0,1,2,3,4,5,6,7]
Y = [0,1,1,0,0,1,1,0]
plt.plot(X,Y)

# %%
import numpy as np
salaries = {
"Mark": 1000,
"John": 1500,   
"Daniel": 2300,
"Greg": 5000
}
salary = list(salaries.values())
names = list(salaries.keys())
salary_data = np.mean(salary)
fig, ax = plt.subplots()
ax.barh(names, salary, color = "green")
# Out:
# <BarContainer object of 4 artists>
